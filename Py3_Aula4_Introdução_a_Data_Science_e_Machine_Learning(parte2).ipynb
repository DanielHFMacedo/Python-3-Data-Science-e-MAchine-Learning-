# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielHFMacedo/Python-3-Data-Science-e-Machine-Learning-Prof-Camila-Dantas-Escola-Fuctura-de-Tecnologia/blob/main/Py3_Aula4_Introdu%C3%A7%C3%A3o_a_Data_Science_e_Machine_Learning(parte2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm 
sns.set_style("darkgrid")
import warnings
warnings.filterwarnings("ignore")

# %%
dados=pd.read_csv('Tetuan City power consumption.csv')

# %%
dados.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
dados.shape
# Out:
# (52416, 9)

# %%
dados.describe
# Out:
# <bound method NDFrame.describe of                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# ...

# %%
dados.columns= ['Data', 'Temperature', 'Humidity', 'Wind_speed', 'general_diffuse_flows', 'diffuse_flows', 'Consumption', 'Consumo1', 'Consumo2']

# %%
dados.drop(columns=["Data", 'Consumo2', 'Consumo1'], inplace=True)

# %%
dados.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind_speed', 'general_diffuse_flows',
#        'diffuse_flows', 'Consumption'],
#       dtype='object')

# %%
dados.describe().round(2)
# Out:
#        Temperature  Humidity  Wind_speed  general_diffuse_flows  \
# count     52416.00  52416.00    52416.00               52416.00
# mean         18.81     68.26        1.96                 182.70
# std           5.82     15.55        2.35                 264.40
# min           3.25     11.34        0.05                   0.00
# 25%          14.41     58.31        0.08                   0.06
# 50%          18.78     69.86        0.09                   5.04
# 75%          22.89     81.40        4.92                 319.60
# max          40.01     94.80        6.48                1163.00
#
#        diffuse_flows  Consumption
# count       52416.00     52416.00
# mean           75.03     32344.97
# std           124.21      7130.56
# min             0.01     13895.70
# 25%             0.12     26310.67
# 50%             4.46     32265.92
# 75%           101.00     37309.02
# max           936.00     52204.40

# %%
dados.cov()
# Out:
#                         Temperature      Humidity   Wind_speed  \
# Temperature               33.819759    -41.623221     6.517185
# Humidity                 -41.623221    241.839112    -4.962395
# Wind_speed                 6.517185     -4.962395     5.517152
# general_diffuse_flows    707.755815  -1924.864643    83.053776
# diffuse_flows            141.956786   -496.208215    -0.283596
# Consumption            18254.905891 -31871.680151  2804.471792
#
#                        general_diffuse_flows  diffuse_flows   Consumption
# Temperature                       707.755815     141.956786  1.825491e+04
# Humidity                        -1924.864643    -496.208215 -3.187168e+04
# Wind_speed                         83.053776      -0.283596  2.804472e+03
# general_diffuse_flows           69907.867473   18546.168144  3.543748e+05
# diffuse_flows                   18546.168144   15428.359933  7.109811e+04
# Consumption                    354374.839451   71098.111241  5.084492e+07
